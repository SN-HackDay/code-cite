# %% [markdown]
# # Citations over time

# %%
# You can ignore this cell, it just imports the different modules you need :smile:
from glob import glob
from IPython.display import display # Use this to display multiple outputs within a cell
import itertools as it
import json
import matplotlib.pylab as plt
# %matplotlib inline
import numpy as np
import os
import pandas as pd
import requests
import seaborn as sns
sns.set_style('white')
sns.set_context('notebook',font_scale=1.5)
from scipy.stats import ttest_ind, ttest_rel, pearsonr, spearmanr, linregress, ttest_1samp
import statsmodels.api as sm
from statsmodels.sandbox.stats.multicomp import fdrcorrection0 as fdr
import sys

# %load_ext autoreload
# %autoreload 2
# Out:
# /home/isla/anaconda3/lib/python3.6/site-packages/statsmodels/compat/pandas.py:56: FutureWarning: The pandas.core.datetools module is deprecated and will be removed in a future version. Please use the pandas.tseries module instead.
#   from pandas.core import datetools

# %% [markdown]
# ## Get the data

# %%
# Taken from a question on StackOverflow:
# https://stackoverflow.com/questions/16694907/how-to-download-large-file-in-python-with-requests-py

def download_file(url, filename):
    local_filename = '../data/{}'.format(filename)
    # NOTE the stream=True parameter
    r = requests.get(url, stream=True)
    with open(local_filename, 'wb') as f:
        for chunk in r.iter_content(chunk_size=1024): 
            if chunk: # filter out keep-alive new chunks
                f.write(chunk)
                #f.flush() commented by recommendation from J.F.Sebastian
    return local_filename

# %%
eupmc_githubdotcom_f_name = 'eupmc_results_githubdotcom.json'
eupmc_githubdotcom_url = 'https://www.dropbox.com/s/4iwwb3mr46pdx2h/{}?dl=1'.format(eupmc_githubdotcom_f_name)

eupmc_zenodo_f_name = 'eupmc_results_zenodo.json'
eupmc_zenodo_url = 'https://www.dropbox.com/s/r7132d9utv17l8j/{}?dl=1'.format(eupmc_zenodo_f_name)

# %%
if not os.path.isdir('../data'):
    os.makedirs('../data')
if not os.path.isfile('../data/{}'.format(eupmc_zenodo_f_name)):
    download_file(eupmc_zenodo_url, eupmc_zenodo_f_name)
else:
    print('eupmc zenodo data already downloaded')

if not os.path.isfile('../data/{}'.format(eupmc_githubdotcom_f_name)):
    download_file(eupmc_githubdotcom_url, eupmc_githubdotcom_f_name)
else:
    print('eupmc githubdotcom data already downloaded')
# Out:
# eupmc githubdotcom data already downloaded

# %% [markdown]
# ## Understand the data

# %%
with open('../data/{}'.format(eupmc_githubdotcom_f_name), encoding="utf8") as f:
    github = json.load(f)
with open('../data/{}'.format(eupmc_zenodo_f_name), encoding="utf8") as f:
    zenodo = json.load(f)

# %%
def affiliations(data):
    affiliation_list = []
    for article in data:
        try:
            for x in article['authorList']:
                for y in x['author']:
                    try:
                        affiliation_list.append(y['affiliation'][0].split(',')[0])
                    except KeyError:
                        pass
        except:
            pass
    from collections import Counter
    affiliations = Counter(affiliation_list)
    return affiliations.most_common()

# %%
affiliations(zenodo)
# Out:
# [('Department of Biology', 100),
#  ('Department of Genetics', 70),
#  ('Department of Medicine', 65),
#  ('Department of Computer Science', 64),
#  ('Department of Neurology', 53),
#  ('Biodiversity Institute of Ontario', 52),
#  ('European Molecular Biology Laboratory', 50),
#  ('European Bioinformatics Institute (EMBL-EBI)', 47),
#  ('Department of Psychology', 39),
#  ('Department of Pathology', 39),
#  ('Department of Chemistry', 35),
#  ('Department of Materials', 34),
#  ('Diamond Light Source Ltd', 34),
#  ('Department of Biological Sciences', 33),
#  ('Department of Psychiatry', 33),
#  ('RCSB Protein Data Bank', 32),
#  ('Department of Life Science Informatics', 31),
#  ('Department of Biochemistry', 30),
#  ('Department of Human Genetics', 29),
#  ('Department of Physics', 29),
#  ('National Center for Emerging and Zoonotic Infectious Diseases and National Center for Immunization and Respiratory Diseases',
#   28),
#  ('Department of Surgery', 25),
#  ('Department of Statistics', 25),
#  ('Bioinformatics Group', 24),
#  ('Department of Biostatistics', 24),
#  ('Institute for Systems Biology', 24),
#  ('Department of Microbiology', 23),
#  ('Molecular Pharmacology Program', 23),
#  ('Wellcome Trust Sanger Institute', 23),
#  ('Institute of Medical Virology', 22),
#  ('Broad Institute of Harvard and MIT', 22),
#  ('Department of Epidemiology', 20),
#  ('Chemistry Research Laboratory', 19),
#  ('Department of Pediatrics', 19),
#  ('Mayo Clinic', 19),
#  ('School of Biological Sciences', 18),
#  ('Helmholtz-Zentrum Dresden - Rossendorf', 18),
#  ('School of Computer Science', 18),
#  ('Department of Life Sciences', 17),
#  ('Technische Universität Dresden', 17),
#  ('Department of Physiology', 17),
#  ('Diamond Light Source', 17),
#  ('Program in Population and Medical Genetics and Genomics Platform', 17),
#  ('Department of Plant Sciences', 16),
#  ('Department of Entomology', 16),
#  ('European Bioinformatics Institute', 16),
#  ('Department of Biomedical Engineering', 16),
#  ('Department of Bioengineering', 15),
#  ('National Center for Biotechnology Information', 15),
#  ('Department of Radiology', 14),
#  ('Clinical Laboratory', 14),
#  ('School of Biosciences', 14),
#  ('European Synchrotron Radiation Facility', 14),
#  ('Department of Animal Science', 14),
#  ('HudsonAlpha Institute for Biotechnology', 14),
#  ('Institute of Structural and Molecular Biology', 14),
#  ('The Donnelly Centre', 14),
#  ('Division of Structural Biology', 14),
#  ('Kenema Government Hospital', 14),
#  ('Institute for Computational Health Sciences', 13),
#  ('Department of Electrical and Computer Engineering', 13),
#  ('Department of Pathology and Laboratory Medicine', 13),
#  ('Department of Zoology', 13),
#  ('National Microbiology Laboratory', 13),
#  ('Lineberger Comprehensive Cancer Center', 13),
#  ('Department of Chemical Engineering', 12),
#  ('Stress Research Institute', 12),
#  ('Nuclear Dynamics Programme', 12),
#  ('School of Life Sciences', 12),
#  ('Department of Biochemistry and Molecular Genetics', 12),
#  ('Federal Research and Clinical Center of Physical-Chemical Medicine of Federal Medical Biological Agency',
#   12),
#  ('Malaghan Institute of Medical Research', 12),
#  ('Department of Molecular Medicine', 12),
#  ('Ontario Institute for Cancer Research', 12),
#  ('The Genome Analysis Centre', 12),
#  ('rare Charitable Research Reserve (Affiliate of)', 12),
#  ('Plant Sciences Department', 12),
#  ('Centre for Inherited Metabolic Diseases', 12),
#  ('Université de Lyon', 11),
#  ('BGI-Shenzhen: Building 11', 11),
#  ('Karolinska Institutet', 11),
#  ('Department of Anesthesiology', 11),
#  ('Repositive Ltd', 11),
#  ('Earlham Institute', 11),
#  ('Department of Biomedical Informatics', 11),
#  ('Department of Medical Informatics and Clinical Epidemiology and OHSU Library',
#   11),
#  ('The Novo Nordisk Foundation Center for Biosustainability', 11),
#  ('IRHS', 11),
#  ('Computer Science and Engineering', 11),
#  ('Sherbrooke Connectivity Imaging Lab (SCIL)', 10),
#  ('Institute of Physics', 10),
#  ('Department of Bioinformatics', 10),
#  ('Department of Ecology and Evolutionary Biology', 10),
#  ('Science for Life Laboratory', 10),
#  ('INRA', 10),
#  ('Molecular and Computational Biology', 10),
#  ('Institute for Computational Biomedicine', 10),
#  ('Department of Mathematics', 10),
#  ('California Digital Library', 10),
#  ('Department of Molecular Genetics', 10),
#  ('Structural Genomics Consortium', 10),
#  ('Sage Bionetworks', 10),
#  ('Radiation Oncology Department', 10),
#  ('Broad Institute of MIT and Harvard', 10),
#  ('Research Department of Genetics', 10),
#  ('Department of Medical Biology', 10),
#  ('University of Oxford', 9),
#  ('Faculty of Medicine', 9),
#  ('Department of Ecology', 9),
#  ('Department of Integrative Biology', 9),
#  ('Harvard University', 9),
#  ('Drug Safety and Metabolism', 9),
#  ('Environmental Genomics and Systems Biology', 9),
#  ('Wellcome Trust Centre for Human Genetics', 9),
#  ('Department of Cancer Biology', 9),
#  ('Faculty of Science and Technology', 9),
#  ('Henan Provincial Chest Hospital', 9),
#  ('Department of Internal Medicine', 9),
#  ('Institute of Pathology', 9),
#  ('Department of Paediatrics', 9),
#  ('Independent Researcher', 9),
#  ('Department of Molecular and Experimental Medicine', 9),
#  ('Massachusetts Host-Microbiome Center', 9),
#  ('School of Biotechnology and Biomolecular Sciences', 9),
#  ('University of California', 8),
#  ('The Francis Crick Institute', 8),
#  ('Shanghai Agrobiological Gene Center; Shanghai Research Station of Crop Gene Resource & Germplasm Enhancement',
#   8),
#  ('Iwate Biotechnology Research Center', 8),
#  ('International Institute of Tropical Agriculture', 8),
#  ('Department of Medical Epidemiology and Biostatistics', 8),
#  ('SIB Swiss Institute of Bioinformatics', 8),
#  ('The Mind Research Network', 8),
#  ('ELIXIR Hub', 8),
#  ('Laboratory of Geographic Information Systems (LASIG)', 8),
#  ('Department of Materials and Department of Bioengineering and Institute of Biomedical Engineering',
#   8),
#  ('Equipe Perception et Design Sonores', 8),
#  ('Department of Medical Physics and Biomedical Engineering', 8),
#  ('Ecological Sciences', 8),
#  ('Department of Pharmacology', 8),
#  ('Institute of Shock Physics', 8),
#  ('Broad Institute', 8),
#  ('Department of Radiation Oncology', 8),
#  ('Department of Computer and Information Sciences', 8),
#  ('Department of Biochemistry and Molecular Biology', 8),
#  ('Cardiovascular Medicine Unit', 8),
#  ('Institute of Biomedical Engineering', 8),
#  ('Computational Biology', 8),
#  ("The Royal Children's Hospital Melbourne", 8),
#  ('Department of Biostatistic', 8),
#  ('Department of Plant and Microbial Biology', 8),
#  ('Norwegian Institute of Public Health', 8),
#  ('BIND-Behavioral Imaging and Neural Dynamics Center', 8),
#  ('Institute of Neuroscience', 8),
#  ('Department of Biological Chemistry and Molecular Pharmacology', 8),
#  ('Department of Psychosis Studies', 8),
#  ('Division of Invertebrate Zoology', 8),
#  ('Vaccine and Infectious Disease Division', 8),
#  ('Molecular Pathology Section', 8),
#  ('Resource for Biocomputing', 8),
#  ('Gladstone Institutes', 8),
#  ('Department of Animal Ecology and Tropical Biology', 8),
#  ('Molecular Medicine Division', 8),
#  ('University College London', 7),
#  ('Department of Electrical Engineering', 7),
#  ('European Molecular Biology Laboratory (EMBL)', 7),
#  ('Department of Ecology and Evolution', 7),
#  ('Department of Microbiology and Biotechnology', 7),
#  ('Center for Brain Science', 7),
#  ('University of Basel', 7),
#  ('Department of Developmental Biology', 7),
#  ('Division of Infectious Diseases', 7),
#  ('Radboud University', 7),
#  ('ELIXIR-UK', 7),
#  ('Oxford e-Research Centre', 7),
#  ('The Jackson Laboratory', 7),
#  ('The Wellcome Trust Sanger Institute', 7),
#  ('Department of Genetics and Genomic Sciences', 7),
#  ('GenPhySE', 7),
#  ('Department of Medical Sciences', 7),
#  ('Department of Pediatric Oncology', 7),
#  ('Deanery of Biomedical Sciences', 7),
#  ('CNRS', 7),
#  ('Experimental Psychology', 7),
#  ('Cancer Research UK Cambridge Institute', 7),
#  ('Computer Assisted Clinical Medicine', 7),
#  ('Luxembourg Centre for Systems Biomedicine', 7),
#  ('Centre for Systems Genomics', 7),
#  ('ARC Centre of Excellence in Plant Energy Biology', 7),
#  ('TGLclinical', 7),
#  ('Wellcome Trust Centre for Cell Biology', 7),
#  ('Department of Computer Science and Engineering', 7),
#  ('Institute for Bio- and Geosciences', 7),
#  ('Department of Anthropology', 7),
#  ('Beijing University Of Chinese Medicine', 7),
#  ('Institut de Pharmacologie Mol´eculaire et Cellulaire', 7),
#  ('Department of Materials ', 7),
#  ('Max Planck Institute of Immunobiology and Epigenetics', 7),
#  ('Centre for Advanced Spatial Analysis (CASA)', 7),
#  ('Institute of Biological', 7),
#  ('Institute of Biology of Komi Scientific Centre of the Ural Branch of the Russian Academy of Sciences',
#   7),
#  ('Institut Pasteur', 6),
#  ('Université Pierre et Marie Curie', 6),
#  ('NatBrainLab', 6),
#  ('Berlin Institute for Medical Systems Biology', 6),
#  ('Core Unit Systems Medicine', 6),
#  ('Center for Comparative Genomics', 6),
#  ('Department of Clinical Neuroscience', 6),
#  ('Present address: JDRF/Wellcome Trust Diabetes and Inflammation Laboratory',
#   6),
#  ('School of Psychology', 6),
#  ('High Energy Density Science Division', 6),
#  ('Department of Molecular and Cellular Biology', 6),
#  ('RIKEN Omics Science Center', 6),
#  ('The Hyve', 6),
#  ('EMBL-EBI', 6),
#  ('Centre for Advanced Electron Spin Resonance (CAESR)', 6),
#  ('Institute of Infection and Global Health', 6),
#  ('Department of Mathematics and Statistics', 6),
#  ('Molecular Foundry', 6),
#  ('Department of Mechanical Engineering', 6),
#  ('Department of Earth and Planetary Sciences', 6),
#  ('VIB Center for Plant Systems Biology', 6),
#  ('Department of Life Science and the Zlotowski Centre for Neuroscience', 6),
#  ('MRC Harwell Institute', 6),
#  ('Mouse Genetics Project', 6),
#  ('Population Ecology Lab', 6),
#  ('Department of Microbiology and Immunology', 6),
#  ('University of California San Diego', 6),
#  ('Department of Experimental Therapeutics', 6),
#  ('Department of Chemistry ', 6),
#  ('Institute of Human Genetics', 6),
#  ('MRC Centre for Regenerative Medicine', 6),
#  ('Systems Biology and Bioinformatics Group', 6),
#  ('John Innes Centre', 6),
#  ('Department of Immunology', 6),
#  ('Mother and Child Health and Development Network (Red SAMID)', 6),
#  ('Lancaster Environment Centre', 6),
#  ('Institute of Computer Assisted Clinical Medicine', 6),
#  ('Department of Mathematical Sciences', 6),
#  ('School of Biological and Chemical Sciences', 6),
#  ('Biology', 6),
#  ('SmarTS Lab', 6),
#  ('Division of Medicinal Chemistry', 6),
#  ('Department of Obstetrics and Gynecology', 6),
#  ('MRC Epidemiology Unit', 6),
#  ('Department of Biostatistics and Computational Biology', 6),
#  ('Institute of Experimental Botany', 6),
#  ('Department of Bioengineering and Therapeutic Sciences', 6),
#  ('Centre for Genomic Research', 6),
#  ('Division of Brain Sciences', 6),
#  ('Associate Professor Fiona Fidler (fidlerfm@unimelb.edu.au) holds a joint appointment in the School of BioSciences and the School of Historical and Philosophical Studies (History and Philosophy of Science Discipline) at the University of Melbourne',
#   6),
#  ('Institute of Molecular Biology', 6),
#  ('Electron Microscopy Science Technology Platform', 6),
#  ('La Trobe Institute for Molecular Science', 6),
#  ('Department of Communication Disorders and Sciences', 6),
#  ('University of Oxford Medical School', 6),
#  ('Department of Medicine II', 6),
#  ('Leibniz Institute of Plant Genetics and Crop Plant Research (IPK)', 6),
#  ("King's College London", 6),
#  ('University of Exeter Medical School', 6),
#  ('Department of Paleobiology', 6),
#  ('Research Program on Biomedical Informatics', 6),
#  ('Department of Cellular and Molecular Medicine', 6),
#  ('Molecular Oncology Laboratories', 6),
#  ('Drug Discovery Unit', 6),
#  ('Institute of Molecular Biology and Tumor Research (IMT)', 6),
#  ('Division Signaling and Functional Genomics', 6),
#  ('Department of Psychological Medicine', 6),
#  ('Biosciences', 6),
#  ('School of Biomolecular and Biomedical Science', 6),
#  ('Veterinary and Diagnostic Production Animal Medicine', 6),
#  ('Center for Biomedical Computing', 6),
#  ('ETH Zürich', 6),
#  ('Department of Genetics and Cambridge Systems Biology Centre', 6),
#  ('PROVIDI Lab', 5),
#  ('Imaging Genetics Center', 5),
#  ('Department of Materials Science and Metallurgy', 5),
#  ('FORTH-ICS', 5),
#  ('EcoHealth Alliance', 5),
#  ('HMS LINCS Center', 5),
#  ('Department of Psychiatry and Psychotherapy', 5),
#  ('Department of Management and Engineering', 5),
#  ('Institute of Biomedicine of Universitat de Barcelona (IBUB) and CSIC-Associated Unit',
#   5),
#  ('Human Genome Sequencing Center', 5),
#  ('Howard Hughes Medical Institute', 5),
#  ('Department of Animal and Plant Sciences', 5),
#  ('Swammerdam Institute for Life Sciences', 5),
#  ('Institute of Biological Sciences', 5),
#  ('Institute of Biodiversity and Ecosystem Research (IBER)', 5),
#  ('Murdoch Childrens Research Institute', 5),
#  ('MOE Key Laboratory of Bioinformatics', 5),
#  ('JDRF/Wellcome Trust Diabetes and Inflammation Laboratory', 5),
#  ('Institute of Evolutionary Biology', 5),
#  ('School of Geography', 5),
#  ('Biological and Soft Matter Physics', 5),
#  ('Institute of Medical and Biological Engineering', 5),
#  ('Institute of Molecular and Cell Biology', 5),
#  ('Institute of Integrative Biology', 5),
#  ('Department of Molecular Oncology', 5),
#  ('Cancer Research UK Clinical Trials Unit', 5),
#  ('Office de la Culture', 5),
#  ('Department for Infectious Disease Epidemiology', 5),
#  ('Department of Population Health and Reproduction', 5),
#  ('Department of Civil and Environmental Engineering', 5),
#  ('EMBL Australia Bioinformatics Resource', 5),
#  ('Faculty of Information Technology', 5),
#  ('Genetics and Experimental Bioinformatics', 5),
#  ('Queensland Brain Institute', 5),
#  ('Marie Bashir Institute for Infectious Diseases and Biosecurity', 5),
#  ('Division of Infectious Diseases and Hospital Epidemiology', 5),
#  ('Harvard Medical School', 5),
#  ('Discovery Sciences', 5),
#  ('Norwegian Institute for Nature Research', 5),
#  ('School of Earth Sciences', 5),
#  ('Department of Systems Biology', 5),
#  ('Bioinformatics and Systems Biology Program', 5),
#  ('National Library of Medicine', 5),
#  ('Enteric Diseases Laboratory Branch', 5),
#  ('Department of Clinical Neuroscience ', 5),
#  ('AMAP', 5),
#  ('Structural Genomics Consortium (SGC)', 5),
#  ('Duke Population Research Institute', 5),
#  ('The Biodesign Institute', 5),
#  ('School of Plant Biology and Institute of Agriculture', 5),
#  ('Center for Genes', 5),
#  ('ICFO-Institut de Ciencies Fotoniques', 5),
#  ('Departments of Materials and Bioengineering', 5),
#  ('Population Sciences Branch', 5),
#  ('Department of Environmental Health', 5),
#  ('Department of Mathematics and Computer Science', 5),
#  ('Division of Genetics and Epidemiology', 5),
#  ('Biogen', 5),
#  ('Ceramics Synthesis and Functionalization Lab', 5),
#  ('Department of Genomic Pathology', 5),
#  ('Dept. Chemistry and Biochemistry', 5),
#  ('Institute of Zoology', 5),
#  ('EMBL', 5),
#  ('EMBL Australia Biomedical Informatics Group', 5),
#  ('MRC Cancer Unit', 5),
#  ('Center for Cancer Research', 5),
#  ('Department of Biological Sciences African Center of Excellence for Genomics of Infectious Diseases',
#   5),
#  ('Department of Broad Institute of Harvard and MIT.', 5),
#  ('School of Electrical Engineering and Computer Science', 5),
#  ('Department of Biotechnology', 5),
#  ('CyVerse', 5),
#  ('Department of Human Biology', 5),
#  ('National Center for Biotechnology', 5),
#  ('Simulation Laboratory Neuroscience - Bernstein Facility for Simulation and Database Technology',
#   5),
#  ('Genome Center', 5),
#  ('Department of Pharmacology and Toxicology', 5),
#  ('Dartmouth-Hitchcock Norris Cotton Cancer Center', 5),
#  ('BioNanoGenomics Inc. 9640 Towne Centre Drive Ste. 100', 5),
#  ('Institute of Biochemistry and Biophysics', 5),
#  ('Literature Service group', 5),
#  ("Centre d'Immunologie de Marseille-Luminy", 5),
#  ('Department of Medical Microbiology and Immunology', 5),
#  ('Animal Genomics Laboratory', 5),
#  ('Global Health Institute', 5),
#  ('National Evolutionary Synthesis Center', 5),
#  ('Museum of Natural Science', 5),
#  ('Tropical Crop and Commodity Protection Research Unit', 5),
#  ('Department of Statistical Simulation', 5),
#  ('Centre for Clinical Intervention and Neuropsychiatric Schizophrenia Research',
#   5),
#  ('Digital Library Research and Prototyping Team', 5),
#  ('Department of Personality', 5),
#  ('Departments of Molecular Genetics and Computer Science', 5),
#  ('Department of Integrative Biology and the Biodiversity Institute of Ontario',
#   5),
#  ('Dept. of Bioengineering', 5),
#  ('Institute of Cognitive Neuroscience', 5),
#  ('Leiden University Medical Center', 4),
#  ('Centre de recherche institut universitaire de geriatrie de Montreal (CRIUGM)',
#   4),
#  ('Signal Processing Lab (LTS5)', 4),
#  ('Medical Imaging Technologies', 4),
#  ('Arthropod-borne and Infectious Diseases Laboratory', 4),
#  ('Department of Medical Genetics', 4),
#  ('Center for Integrative Neuroscience', 4),
#  ('Genomics and Computational Biology Graduate Program', 4),
#  ('ICREA', 4),
#  ('IPHYS', 4),
#  ('Centre for Behaviour and Evolution', 4),
#  ('Japan International Research Center for Agricultural Sciences', 4),
#  ('Department of Neurosurgery', 4),
#  ('Stanford Center for Biomedical Informatics Research', 4),
#  ('Graduate Institute of Biomedical Electronics and Bioinformatics', 4),
#  ('SLU-Global Bioinformatics Centre', 4),
#  ('Conservation', 4),
#  ('Laboratory of Entomology', 4),
#  ('Actual Analytics Ltd', 4),
#  ('Hit Discovery', 4),
#  ('PUCRS', 4),
#  ('Department of Earth Sciences', 4),
#  ('Cognitronics and Sensor Systems', 4),
#  ('Medical Intensive Care Unit', 4),
#  ('School of BioSciences', 4),
#  ('Lygature', 4),
#  ('Interface Analysis Centre', 4),
#  ('Cytognomix Inc.', 4),
#  ('The Center for Global Safe Water', 4),
#  ('Department of Urology', 4),
#  ('Advanced Technology Institute and SEPNet', 4),
#  ('Soft Matter Physics', 4),
#  ('Institute of Environmental Health Sciences', 4),
#  ('School of Agriculture', 4),
#  ('Laboratorio de Interacciones Insecto-Planta', 4),
#  ('The Norwegian Structural Biology Center', 4),
#  ('Veterinary Genetics Laboratory', 4),
#  ('Department of Physics and Astronomy and Interdisciplinary Nanoscience Center iNANO',
#   4),
#  ('Department of Medical Informatics and Epidemiology and OHSU Library', 4),
#  ('Fred Hutchinson Cancer Research Center', 4),
#  ('Department of Statistics and O.R. School of Mathematical Sciences', 4),
#  ('Department of Oncology', 4),
#  ('Entomology', 4),
#  ('Department for Clinical Psychology and Psychotherapy', 4),
#  ('Centers for Disease Control and Prevention', 4),
#  ('Biomedical Research Foundation', 4),
#  ('Department of Psychiatry and Behavioral Sciences', 4),
#  ('Department of Atmospheric and Oceanic Sciences', 4),
#  ('Imperial College London', 4),
#  ('The University of Texas Health Science Center at Houston', 4),
#  ('Department of Systems Biology and Bioinformatics', 4),
#  ('Center for Behavioral Brain Sciences', 4),
#  ('Département de Biologie', 4),
#  ('Center for RNA interference and non-coding RNA', 4),
#  ('Unité de recherche sur les maladies infectieuses et tropicales émergentes (URMITE)',
#   4),
#  ('Department of Epidemiology and Biostatistics', 4),
#  ('New York Genome Center', 4),
#  ('Department of Clinical Genetics', 4),
#  ('Institute of Organic Chemistry and Biochemistry', 4),
#  ('The Hudson Institute of Medical Research and Department of Anatomy', 4),
#  ('Wolfson Centre for Mathematical Biology', 4),
#  ('Jane Anne Nohl Division of Division of Hematology and Center for the Study of Blood Diseases',
#   4),
#  ('Genetics', 4),
#  ('Institute for Integrative Genome Biology', 4),
#  ('Sino-US International Research Centers of Tuberculosis', 4),
#  ('Ghrelin Research Group', 4),
#  ('Division of Epidemiology', 4),
#  ('Department of Neuroscience', 4),
#  ('Dept. Earth Sciences', 4),
#  ('Institute of Ageing and Chronic Disease', 4),
#  ('Mouse Informatics Group', 4),
#  ('Finnish Environment Institute SYKE', 4),
#  ('University of Sydney', 4),
#  ('InBioS-PhytoSYSTEMS', 4),
#  ('Department of Organismic and Evolutionary Biology', 4),
#  ('Department of Molecular and Systems Biology', 4),
#  ('Biological Sciences', 4),
#  ('Department of Pneumology', 4),
#  ('InIT-Institute Industrial IT', 4),
#  ('School of Medicine', 4),
#  ('School of Computer Science and Technology', 4),
#  ('Genetics and Office of Information Technology', 4),
#  ('Biodemography of Aging Research Unit (BARU) at Social Science Research Institute',
#   4),
#  ('CNRS UMR 3525', 4),
#  ('UnivLyon', 4),
#  ('Sandia National Laboratories', 4),
#  ('U.S. Naval Medical Research Unit No. 6', 4),
#  ('University of Chinese Academy of Sciences', 4),
#  ('Unité Mixte de Recherche 1345', 4),
#  ('Open Lab', 4),
#  ('Istituto Italiano di Antropologia', 4),
#  ('Dipartimento di Scienze Biologiche', 4),
#  ('Bernhard Nocht Institute for Tropical Medicine', 4),
#  ('Weill Institute for Cell and Molecular Biology', 4),
#  ('Department of Materials Science and Engineering', 4),
#  ('Philipps-University Marburg', 4),
#  ('6 Division of Biomedical Sciences', 4),
#  ('The University of Queensland Diamantina Institute', 4),
#  ('Department of Immunobiology', 4),
#  ('Neuroscience TA', 4),
#  ('German Center for Diabetes Research (DZD e.V.)', 4),
#  ('Cardiovascular Health Research Unit', 4),
#  ('Center for Epigenetics', 4),
#  ('Department of Critical Care Medicine', 4),
#  ('Univ. Grenoble Alpes', 4),
#  ('Division of Anatomy', 4),
#  ('Department of Infectious Diseases and Microbiology', 4),
#  ('Sleep and Circadian Neuroscience Institute (SCNi)', 4),
#  ('Centre for Neural Circuits and Behaviour', 4),
#  ('Laboratory of Molecular Biology', 4),
#  ('Forschungszentrum Jülich GmbH', 4),
#  ('Evolution', 4),
#  ("Programme Cartes d'Identité des Tumeurs", 4),
#  ("Barbra Streisand Women's Heart Center", 4),
#  ('Department of Preventive Medicine', 4),
#  ('Department of Gynecology and Obstetrics', 4),
#  ('Laboratory of Cellular and Structural Biology', 4),
#  ('Institute of Advanced Studies', 4),
#  ('Department of Biology and Biochemistry', 4),
#  ('Interdisciplinary Computing and Complex BioSystems (ICOS) research group',
#   4),
#  ('Biotechnology High Performance Computing Software Applications Institute',
#   4),
#  ('Equipe AIRE', 4),
#  ('Department of Biosystems Science and Engineering', 4),
#  ('Department of Biomedical Sciences and CRIBI Biotechnology Center', 4),
#  ('Laboratory of Experimental Psychology', 4),
#  ('School of Biological Sciences at Flinders University', 4),
#  ('Genome Institute of Singapore', 4),
#  ('Nuffield Department of Clinical Medicine', 4),
#  ('Clinic Barmelweid', 4),
#  ('Max Planck Institute for the Physics of Complex Systems ', 4),
#  ('Department of Community Medicine', 4),
#  ('Division of Molecular Carcinogenesis', 4),
#  ('Cancer Epigenetics and Biology Program (PEBC)', 4),
#  ('African Center of Excellence for Genomics of Infectious Diseases', 4),
#  ('Statistics Department', 4),
#  ('National Center for Genome Resources', 4),
#  ('Institute for Molecular Life Sciences', 4),
#  ('Department of Agri-Food Production and Environmental Science', 4),
#  ('Genomics Core Facility', 4),
#  ('Research Centre for Infectious Diseases (ZINF)', 4),
#  ('Deutsches Elektronen-Synchrotron DESY', 4),
#  ('Department of Cognitive Psychology', 4),
#  ('Department of Cardiothoracic Anaesthesiology', 4),
#  ('Center for Plant Biotechnology and Genomics', 4),
#  ('Department of Microbiology and Plant Biology', 4),
#  ('Department of Biotechnology and Biosciences', 4),
#  ('Natural Resources Canada', 4),
#  ('ArtDatabanken', 4),
#  ('Centre for Molecular and Biomolecular Informatics', 4),
#  ('Division of Chemistry and Chemical Engineering 210-41', 4),
#  ('South London and Maudsley NHS Foundation Trust', 4),
#  ('Department of Environmental Biology', 4),
#  ('Departamento de Tecnologia', 4),
#  ('Institute of Virology', 4),
#  ('Department of Applied Computer and Biosciences', 4),
#  ('CRBS', 4),
#  ('School of Engineering', 4),
#  ('Centre for Bioinformatics', 4),
#  ('Genouest Bioinformatics Facility', 4),
#  ('Department of Microbiology and Molecular Genetics', 4),
#  ('Dietrich College of Humanities and Social Sciences/Department of Psychology/Auditory Laboratory',
#   4),
#  ('Department of Physics and Center for Biological Physics', 4),
#  ('IBM', 4),
#  ('Departamento de Genética e Biologia Evolutiva', 4),
#  ('Faculty of Health Studies', 4),
#  ('Microbiology and Molecular Genetics', 4),
#  ('UCD Conway Institute of Biomolecular and Biomedical Research', 4),
#  ('rare Charitable Research Reserve', 4),
#  ('Museo Argentino de Ciencias Naturales "Bernardino Rivadavia" (MACN-CONICET)',
#   4),
#  ('University of Guelph', 4),
#  ('Bioinformatics & Computational Biology Laboratory', 4),
#  ('Biodiversity Research Centre', 4),
#  ('Institute of Plant Sciences', 4),
#  ('Zoophysiology', 4),
#  ('Laboratory of Apiculture and Social Insects', 4),
#  ('Department of Infectious Disease Epidemiology', 4),
#  ('Department of Electrical Engineering (ESAT) STADIUS Center for Dynamical Systems',
#   4),
#  ('California Institute for Quantitative Biosciences', 4),
#  ('European Bioinformatics Institute EMBL-EBI', 4),
#  ('Max Planck Institute of Biochemistry', 4),
#  ('TUM', 4),
#  ('Kusuma School of Biological Sciences', 4),
#  ('Dpto. de Genética', 4),
#  ('Lukuru Wildlife Research Foundation', 3),
#  ('Inria Saclay-Ile-de-France and Université Paris Saclay', 3),
#  ('University of Helsinki', 3),
#  ('Universitat de Barcelona', 3),
#  ('University Hospital Zurich', 3),
#  ('Zoological Institute and Museum', 3),
#  ('Department of Molecular Sensory Systems', 3),
#  ('Department of Diagnostic Imaging', 3),
#  ('Institute of Information Processing and Automation', 3),
#  ('Neuroimaging Unit', 3),
#  ('Division of Biostatistics', 3),
#  ('Institute of Neuroscience and Centre for Behaviour and Evolution', 3),
#  ('Institute for Tropical Biology and Conservation', 3),
#  ('Cambridge Graphene Centre', 3),
#  ('CeMM Research Center for Molecular Medicine of the Austrian Academy of Sciences',
#   3),
#  ('CREAF', 3),
#  ('Universidad de Zaragoza', 3),
#  ('LINCS-BD2K DCIC', 3),
#  ('Australian Research Council Centre of Excellence for Coral Reef Studies',
#   3),
#  ('Research Unit Analytical BioGeoChemistry', 3),
#  ('Department of Molecular Microbiology and Immunology', 3),
#  ('Virus Genomics', 3),
#  ('School of Chemistry', 3),
#  ('International Union of Crystallography', 3),
#  ('California Academy of Sciences', 3),
#  ('Institute of Biodiversity', 3),
#  ('Department of Bioinformatics and Computational Biology', 3),
#  ('The Earlham Institute', 3),
#  ('National Institute for Public Health and the Environment', 3),
#  ('School of Computing', 3),
#  ('Centro de Biologia Molecular e Ambiental (CBMA) / Sociedade Portuguesa de Vida Selvagem (SPVS)',
#   3),
#  ('School of Informatics', 3),
#  ('Singapore University of Technology and Design', 3),
#  ('National Health Service Blood and Transplant', 3),
#  ('Institute for Engineering and Computational Mechanics', 3),
#  ('Universität Rostock', 3),
#  ('Data 2 Knowledge Research Group', 3),
#  ('RIKEN Center for Life Science Technologies', 3),
#  ('Department of Earth Science and Engineering', 3),
#  ('Science and Technology Facilities Council', 3),
#  ('Stockholm University', 3),
#  ('MRC Human Genetics Unit', 3),
#  ('Clinical Neurosciences', 3),
#  ('Department of Cardiology', 3),
#  ('Department of Obstetrics and Gynaecology', 3),
#  ('Netherlands Cancer Institute', 3),
#  ('Transcriptome Bioinformatics', 3),
#  ('University of Nebraska-Lincoln', 3),
#  ('Laboratoire de Biométrie et Biologie Evolutive', 3),
#  ('BioProcess Engineering Group. IIM-CSIC', 3),
#  ('Computational Bioscience Research Center', 3),
#  ('WHO Collaborating Centre for Infectious Disease Epidemiology and Control',
#   3),
#  ('Department of Otolaryngology', 3),
#  ('Université de Montréal', 3),
#  ('Institute of Biotechnology', 3),
#  ('Biochemical Engineering Institute', 3),
#  ('Department of Genome Sciences', 3),
#  ('Institució Catalana de Recerca i Estudis Avançats (ICREA)', 3),
#  ('Department of Chemical Engineering and Biotechnology', 3),
#  ('Biodemography of Aging Research Unit (BARU) at Social Sciences Research Institute (SSRI)',
#   3),
#  ('Meyer Cancer Center', 3),
#  ('Equipe Interaction Sons Musique Mouvement', 3),
#  ('Institute of Social and Preventive Medicine', 3),
#  ('Departamento de Biologia Geral', 3),
#  ('Institute for Synthetic Microbiology', 3),
#  ('Molecular Design Institute', 3),
#  ('George Washington University School of Medicine & Health Sciences', 3),
#  ('Department of Otorhinolaryngology', 3),
#  ('Moscow Institute for Physics and Technology', 3),
#  ('DG Joint Research Centre', 3),
#  ('Plant and Crop Sciences', 3),
#  ('Department of Infectious Diseases', 3),
#  ('Discipline of Zoology', 3),
#  ('Laboratório de Evolução de Mamíferos', 3),
#  ('Santa Fe Institute', 3),
#  ('Swedish Meteorological and Hydrological Institute (SMHI)', 3),
#  ('Centre for Advanced Electron Spin Resonance', 3),
#  ('School of Earth and Environment', 3),
#  ('Institute of Environmental Medicine', 3),
#  ('Department of Bioinformatics-BiGCaT', 3),
#  ('Department of Bacteriology', 3),
#  ('Center for Nanostructured Graphene', 3),
#  ('Center for Research in Biological Systems', 3),
#  ('Center for Biological Sequence Analysis', 3),
#  ('London Centre of Nanotechnology', 3),
#  ('Department of Physics and Astronomy', 3),
#  ('Cancer Research UK Cambridge Institute (CRUK-CI)', 3),
#  ('ImmunoTechnology Section', 3),
#  ('Cancer Research UK/MRC Oxford Institute for Radiation Oncology', 3),
#  ('Dept of Psychiatry', 3),
#  ('Biomedical Primate Research Centre', 3),
#  ('Center for Integrative Genomics', 3),
#  ('Winship Cancer Institute of Emory University', 3),
#  ('Department of EcologySwedish University of Agricultural SciencesUppsalaSweden.',
#   3),
#  ('Institute for Hydraulic and Water Resources EngineeringTU Wien', 3),
#  ('Netherlands eScience Center', 3),
#  ('Software Sustainability Institute', 3),
#  ('Center for Open Science', 3),
#  ('Department of BiologyMcGill UniversityMontrealQCCanada.', 3),
#  ('PreCyte Inc.', 3),
#  ('Membrane and DNA Dynamics Team', 3),
#  ('Adaptive Biotechnologies', 3),
#  ('Photonics Group', 3),
#  ('Computational Medicine Center', 3),
#  ('Department of Gastrointestinal Medical Oncology', 3),
#  ('Program in Medical and Population Genetics', 3),
#  ('Institute for Psychology', 3),
#  ('GSPA research Laboratory (Management of Animal Health and Productions)', 3),
#  ('Program in Bioinformatics and Integrative Biology', 3),
#  ('Joint BSC-CRG-IRB Research Program in Computational Biology', 3),
#  ('Université Paris Diderot', 3),
#  ('Biology Department', 3),
#  ('Computational Biology Program', 3),
#  ('Human Oncology and Pathogenesis Program', 3),
#  ('School of Computing Science', 3),
#  ('National Institute of Environmental Health Sciences', 3),
#  ('Brain State Decoding Lab', 3),
#  ('Machine Learning Group', 3),
#  ('Epigenetics Programme', 3),
#  ('Institut des Sciences Chimiques de Rennes (Equipe MaCSE) ', 3),
#  ('Brain and Cognition Research Unit', 3),
#  ('Helmholtz-Zentrum Berlin für Materialien und Energie GmbH', 3),
#  ('Centro Cardiologico Monzino', 3),
#  ('Agriculture and Agri-Food Canada', 3),
#  ('Division of Pulmonary', 3),
#  ('Imperial College', 3),
#  ('Research Complex at Harwell', 3),
#  ('School of Biomedical Sciences', 3),
#  ('Ideaconsult Ltd.', 3),
#  ('Medical Genetics Unit', 3),
#  ('Department of Pathology & Laboratory Medicine and UCLA Clinical Genomics Center',
#   3),
#  ('Institute of Molecular Infection Biology', 3),
#  ('School of Marine and Environmental Affairs', 3),
#  ('Departamento de Ciências Biológicas', 3),
#  ('Columbia University', 3),
#  ('Department of Ophthalmology', 3),
#  ('Center for Computing Research', 3),
#  ('The T.K.P. Research Center for Photonics', 3),
#  ('Departments of Medicine and Microbiology', 3),
#  ('Oxford Genomics Centre', 3),
#  ('Institut für Neuroinformatik', 3),
#  ('UK Biobank', 3),
#  ('Faculty of Medicine and Pharmacy', 3),
#  ('Institute of Clinical Radiology and Nuclear Medicine', 3),
#  ('Bioinformatics Program', 3),
#  ('Institute of Medical Genetics', 3),
#  ('The Crick Institute', 3),
#  ('Department of Molecular Biology and Ecology of Plants', 3),
#  ('Saint-Petersburg National Research Academic University of the Russian Academy of Science',
#   3),
#  ('Centre for Biomembrane Research', 3),
#  ('2 Nuffield Department of Orthopaedics', 3),
#  ('Department of Molecular Physiology and Biological Physics', 3),
#  ('Duke-NUS Medical School', 3),
#  ('Department of Aeronautics Imperial College', 3),
#  ('Human Genetics Center', 3),
#  ('Institute of Epidemiology II', 3),
#  ('University of Queensland Diamantina Institute', 3),
#  ('Molecular Systems Engineering Group Centre for Process Systems Engineering Department of Chemical Engineering',
#   3),
#  ('Marie Bashir Institute of Infectious Diseases and Biosecurity', 3),
#  ('GSK', 3),
#  ("The Children's Hospital at Westmead", 3),
#  ('Intensive Care Unit', 3),
#  ('Domain of Infectious Disease Control and Environmental Health', 3),
#  ('Max Planck Institute of Molecular Cell Biology and Genetics', 3),
#  ('Department of Biophysics', 3),
#  ('Institute of Plant Genetics', 3),
#  ('Genome Science Division', 3),
#  ('Justus-Liebig-University Giessen', 3),
#  ('inIT-Institute Industrial IT', 3),
#  ('Department of Molecular Biology', 3),
#  ('Psychoinformatics Lab', 3),
#  ('Experimental Psychology Lab', 3),
#  ('Computational Systems Chemistry', 3),
#  ('Murdoch Childrens Research Institute and Department of Paediatrics', 3),
#  ("The Royal Women's Hospital", 3),
#  ('Section of Neonatal Genetics', 3),
#  ('Department of Translational Research in Psychiatry', 3),
#  ('Division of Gastroenterology', 3),
#  ('Department of Clinical Sciences', 3),
#  ('Molecular Genetics Group', 3),
#  ('Department of Animal Ecology and Tropical Biology (Zoology III)', 3),
#  ('Brain Function Research Group', 3),
#  ('Division of Psychiatry', 3),
#  ('Computational Geo-Ecology', 3),
#  ('Information Science', 3),
#  ('Information & Data Centre', 3),
#  ('Department of Genomic Medicine', 3),
#  ('Active Perception Lab', 3),
#  ('Department of Stem Cell Transplantation', 3),
#  ('School of Automation and Electrical Engineering', 3),
#  ('IMASL-CONICET', 3),
#  ('Department of Molecular Biology and Biochemistry', 3),
#  ('Population Health and Reproduction', 3),
#  ('Genetically Defined Diseases and Genomics', 3),
#  ('Department of Broad Institute of Harvard and MIT Department of FAS Center for Systems Biology',
#   3),
#  ('UCL Institute of Cognitive Neuroscience', 3),
#  ("Istituto di Scienza e Tecnologia dell'Inquinamento Luminoso (Light Pollution Science and Technology Institute)",
#   3),
#  ('Computing Science', 3),
#  ('Institut de Biologie Intégrative et des Systèmes (IBIS)', 3),
#  ('McGill University', 3),
#  ('Institut des sciences de la mer de Rimouski', 3),
#  ('Université Laval', 3),
#  ('ARUP Institute for Clinical and Experimental Pathology', 3),
#  ('USTAR Center for Genetic Discovery', 3),
#  ('Clinic for Gynecology', 3),
#  ('Laboratório de Citogenética de Insetos', 3),
#  ('Department of Biomedical Informatics and Medical Education', 3),
#  ('Lawrence Berkeley National Laboratory', 3),
#  ('Lady Davis Research Institute', 3),
#  ('Princess Margaret Cancer Centre', 3),
#  ('Department of Biochemistry and Structural Biology', 3),
#  ('Department of Information Engineering', 3),
#  ('Medical Physics Department', 3),
#  ('Wageningen Seed Lab', 3),
#  ("St. Vincent's Clinical School", 3),
#  ('Centre for Ecology', 3),
#  ('Centro de Investigação das Ferrugens do Cafeeiro', 3),
#  ('Neuroscience Center', 3),
#  ('Institute for Research in Immunology and Cancer', 3),
#  ('Institute of Applied Microbiology', 3),
#  ('Oxford e-Research Center', 3),
#  ('Erasmus MC', 3),
#  ('Department of Linguistics', 3),
#  ('Department of Organismal Biology and Anatomy', 3),
#  ('Institut National de la Recherche Agronomique (INRA)', 3),
#  ('Comparative Genomics Laboratory', 3),
#  ('NE-CAT and Department of Chemistry and Chemical Biology', 3),
#  ('Department of Molecular Biology and Genetics', 3),
#  ('Center for Translational Genomics and Bioinformatics', 3),
#  ('Highly Pathogenic Viruses (ZBS 1)', 3),
#  ('Biological Toxins (ZBS 3)', 3),
#  ('Auditory Perception Lab', 3),
#  ('School of Laboratory Medicine', 3),
#  ('Samples', 3),
#  ('Department of Industrial and Systems Engineering', 3),
#  ('The HRH Prince Alwaleed Bin Talal Bin Abdulaziz Alsaud Institute for Computational Biomedicine',
#   3),
#  ('Division of Public Health Sciences', 3),
#  ('São Paulo Institute of Tropical Medicine', 3),
#  ('Biomedical Image Technologies', 3),
#  ('National Centre for Text Mining (NaCTeM)', 3),
#  ('Université catholique de Louvain', 3),
#  ('Radboud Institute for Molecular Life Sciences', 3),
#  ('Cell and Matrix Biology', 3),
#  ('Departamento de Ecologia', 3),
#  ('Natural Capital Project', 3),
#  ('Institute on the Environment (IonE)', 3),
#  ('Safety and Environmental Assurance Centre', 3),
#  ('Wyss Institute for Biologically Inspired Engineering', 3),
#  ('Priority Program Infections', 3),
#  ('Arizona Genomics Institute', 3),
#  ('Department of Sleep Medicine', 3),
#  ('Centre for Physical Activity and Nutrition Research', 3),
#  ('Integrative Genomics of Ageing Group', 3),
#  ('Institute for Experimental Surgery', 3),
#  ('Institute for Biochemistry', 3),
#  ('Department of Botany', 3),
#  ('Institute of Organic Chemistry and Chemical Biology', 3),
#  ('Department of Oncology Biostatistics & Bioinformatics', 3),
#  ('Flowers Team', 3),
#  ('Laboratory of Microbiology and Biotechnology of Foods', 3),
#  ('Laboratory of Pharmaceutical Microbiology', 3),
#  ('College of Computer', 3),
#  ('UCD School of Veterinary Medicine', 3),
#  ('University of Waikato', 3),
#  ('University of Oulu', 3),
#  ('Department of Clinical and Experimental Medicine', 3),
#  ('Food and Agriculture Organization of the UN', 3),
#  ('Department of Neurosciences', 3),
#  ('US Army Medical Research Institute of Infectious Diseases', 3),
#  ('Tulane University', 3),
#  ('Leibniz-Institut für Kristallzüchtung', 3),
#  ('PRISM BioLab Corporation', 3),
#  ('Pôle Génotypage des Pathogènes', 3),
#  ('Institute of Ecology and BotanyCentre for Ecological ResearchHungarian Academy of SciencesVácrátótHungary.',
#   3),
#  ('Division of Biology and Medicine', 3),
#  ('School of Engineering and Informatics', 3),
#  ('Department of Earth', 3),
#  ('Epigenetics Research Program', 3),
#  ('Institute for Advanced Biosciences', 3),
#  ('The Roslin Institute and Royal (Dick) School of Veterinary Studies', 3),
#  ('Department of Clinical and Molecular Biomedicine', 3),
#  ('Broad Institute of Massachusetts Institute of Technology and Harvard', 3),
#  ('GNR Knowledge Centre for Genome Informatics', 3),
#  ('Key Laboratory of Combinatorial Biosynthesis and Drug Discovery', 3),
#  ('Computational Biology Group', 3),
#  ('Bioinformatics Institute', 3),
#  ('The European Molecular Biology Laboratory', 3),
#  ('Center for Computational Biology', 3),
#  ('Department of Immunology and Infectious Diseases', 2),
#  ('Institute of Evolutionary Biology and Centre for Immunity', 2),
#  ('Epidemiology', 2),
#  ('Heidelberg Institute for Theoretical Studies', 2),
#  ('Institute of Complex Systems and Institute for Advanced Simulation', 2),
#  ('Division of Medical Image Computing', 2),
#  ('United Imaging Healthcare Co.', 2),
#  ('Synaptive Medical Inc.', 2),
#  ('Department of Wind Energy', 2),
#  ('Max Planck Institute for Informatics', 2),
#  ('Group of Immune Response Regulation', 2),
#  ('Interdisciplinary Centre for Bioinformatics', 2),
#  ('Laboratorio de Parasitología', 2),
#  ('UoN Chair of Oman Medicinal Plants and Marine Products', 2),
#  ('Department of Biological Sciences and Chemistry', 2),
#  ('Physics of Cognition Group', 2),
#  ('IUCN SSC Spider and Scorpion Specialist Group', 2),
#  ('Key Laboratory of Eco-Textile', 2),
#  ('L-NESS', 2),
#  ('General Bioinformatics', 2),
#  ("Institut de Biologie de l'Ecole Normale Supérieure (IBENS)", 2),
#  ('Department of Mechanical and Aerospace Engineering', 2),
#  ('Departments of Biology and Computer Science', 2),
#  ('Department of Electrical and Biomedical Engineering', 2),
#  ('Servei de Control de Mosquits del Consell Comarcal del Baix Llobregat', 2),
#  ('School of Earth and Environmental Sciences', 2),
#  ('Universidad de Murcia', 2),
#  ('Department of Ecology and Genetics', 2),
#  ('Earth and Biological Sciences Directorate', 2),
#  ('Institute of Microbiology', 2),
#  ("Children's Hospital Oakland Research Institute", 2),
#  ('Department of Neurophysics & Marburg Center for Mind', 2),
#  ('Information Systems Institute at the University of Applied Sciences Western Switzerland (HES-SO Valais)',
#   2),
#  ('Bioinformatics Core', 2),
#  ('Division of Systematic Proteome Research and Bioanalytics', 2),
#  ('Molecular Plant Genetics', 2),
#  ('Chan Zuckerberg Biohub', 2),
#  ('UMR 7205 Institut de Systématique', 2),
#  ('Department of Medical Imaging', 2),
#  ('School of Life and Environmental Sciences', 2),
#  ('Crystal and Structural Chemistry', 2),
#  ('Ontology Engineering Group', 2),
#  ('Biomedical Informatics Group', 2),
#  ('Virginia Commonwealth University', 2),
#  ('Institute of Ecology and Evolutionary Biology', 2),
#  ('Museum of Vertebrate Zoology', 2),
#  ('Faculty of Physics', 2),
#  ('School of Psychology and Neuroscience', 2),
#  ('Arthritis Research UK Centre for Epidemiology', 2),
#  ('NIHR Manchester Biomedical Research Centre', 2),
#  ('Agricultural Research Council-The Biotechnology PlatformOnderstepoort', 2),
#  ('Warwick Medical School', 2),
#  ('Cavendish Laboratory', 2),
#  ('Kyoto Sangyo University', 2),
#  ('The Sainsbury Laboratory', 2),
#  ('Harvard Medical School Department of Immunology', 2),
#  ('INSERM', 2),
#  ('K.G. Jebsen Coeliac Disease Research Centre', 2),
#  ('Departamento de Biología de la Conservación', 2),
#  ('Centre for Crop Systems Analysis', 2),
#  ('Life Sciences Institute', 2),
#  ('Quantitative Biology', 2),
#  ('NC3Rs', 2),
#  ('AgriLife Genomics and Bioinformatics', 2),
#  ('Department of Neurobiology', 2),
#  ('MRC Biostatistics Unit', 2),
#  ('Biomechanics and Biorobotics', 2),
#  ('Leibniz ScienceCampus Primate Cognition', 2),
#  ('National Human Genome Research Institute', 2),
#  ('Department of Applied Physics', 2),
#  ('EMBL-European Bioinformatics Institute', 2),
#  ('National Research Council of Italy (CNR)', 2),
#  ('Computational Engineering and Design', 2),
#  ('Singapore Institute of Manufacturing Technology', 2),
#  ('Institute of Bioinformatics', 2),
#  ('Computer Architecture Group. Department of Electronics and Systems. University of A Coruña. Campus de Elviña s/n. 15071 A Coruña',
#   2),
#  ('School of Metallurgy and Materials', 2),
#  ('Department of Molecular Pharmacology and Experimental Therapeutics', 2),
#  ('Department of Health Sciences Research', 2),
#  ('Biodesign', 2),
#  ('DKFZ-ZMBH Alliance', 2),
#  ('Université de Sherbrooke', 2),
#  ("Institut de l'Elevage", 2),
#  ('Universitat Pompeu Fabra (UPF)', 2),
#  ('The Access Project Rwanda', 2),
#  ('International Committee of the Red Cross', 2),
#  ('Ludwig Institute for Cancer Research', 2),
#  ('Electrical and Computer Engineering', 2),
#  ('Bioimaging and Optics Platform (BIOP)', 2),
#  ('Swiss Institute for Experimental Cancer Research (ISREC)', 2),
#  ('Warwick Centre for Predictive Modelling', 2),
#  ('Curriculum in Bioinformatics and Computational Biology', 2),
#  ('London Centre for Nanotechnology and Department of Physics and Astronomy',
#   2),
#  ('Graduate Group in Biostatistics', 2),
#  ('Division of Biostatistics and Epidemiology', 2),
#  ('Institute for Theoretical Biology', 2),
#  ('Molecular Biology of Archaea', 2),
#  ('University of Illinois at Urbana-Champaign', 2),
#  ('Instituto Nacional de Pesquisas da Amazônia', 2),
#  ('BioTechMed', 2),
#  ('Institute of Fundamental Medicine and Biology of Kazan Federal University',
#   2),
#  ('State Scientific Center of Coloproctology', 2),
#  ('Moscow State University of Medicine and Dentistry named after A.I. Evdokimov',
#   2),
#  ('Institut de Biologie Computationnelle', 2),
#  ('Department of Immunology and Microbiology', 2),
#  ('Department of Exact Sciences', 2),
#  ('Departamento de Ciencia de los Materiales', 2),
#  ('Distinguished Scientist Fellowship Program', 2),
#  ('Research Center for Infectious Diseases', 2),
#  ('HLA Laboratory', 2),
#  ('Department of Biology and Ecology', 2),
#  ('Department of Anesthesia', 2),
#  ('Institute for Biostatistics', 2),
#  ('Department of Systematic and Evolutionary Botany', 2),
#  ('Interdisciplinary Center for Bioinformatics', 2),
#  ('Bayer CropScience N.V.', 2),
#  ('Département des sciences biologiques', 2),
#  ('Fisheries and Oceans Canada', 2),
#  ('Geospatial Research Ltd', 2),
#  ('Department of Clinical Pathology', 2),
#  ('Large Animal Clinical Sciences', 2),
#  ('ELIXIR-Netherlands', 2),
#  ('ELIXIR-Switzerland', 2),
#  ('Helsinki Institute for Information Technology HIIT', 2),
#  ('Institute for Molecular Medicine Finland', 2),
#  ('ICOS research group', 2),
#  ('RNA Bioscience Initiative', 2),
#  ('Berkeley Natural History Museums', 2),
#  ('Babraham Institute', 2),
#  ('Leiden Institute of Advanced Computer Science', 2),
#  ('Department of Electronic and Electrical Engineering', 2),
#  ('Keysight Laboratories', 2),
#  ("Section d'archéologie et paléontologie", 2),
#  ('Colectivo Arqueológico-Paleontológico Salense', 2),
#  ('Human and Molecular Genetics', 2),
#  ('Mouse Biology Program', 2),
#  ('Model Animal Research Center', 2),
#  ('Université de Strasbourg', 2),
#  ('The Hospital for Sick Children', 2),
#  ('BioResource Center', 2),
#  ('Centre for Computational Biology', 2),
#  ('Division of Biological Sciences', 2),
#  ('Software Carpentry Foundation', 2),
#  ('Centre for Ecological and Evolutionary Synthesis', 2),
#  ('Madagascar Biodiversity Center', 2),
#  ('Department of Structural Biology', 2),
#  ("Hawai'i Institute of Marine Biology", 2),
#  ('Mammal Research Institute', 2),
#  ('IMBiV', 2),
#  ('Department of Applied Entomology', 2),
#  ('Department of Biostatistics and Bioinformatics', 2),
#  ('ELIXIR-DE and de.NBI', 2),
#  ('ELIXIR-SE', 2),
#  ('Dutch TechCenter for Life Sciences and ELIXIR-NL', 2),
#  ('Centre for Language and Speech Technology', 2),
#  ('University of Manitoba', 2),
#  ('Center for Infectious Disease Research (formerly Seattle Biomedical Research Institute)',
#   2),
#  ('Department of Chemical and Pharmaceutical Sciences and ICCOM Trieste Research Unit',
#   2),
#  ('Lineberger Comprehensive Cancer Center.', 2),
#  ('Inter-university Consortium for Political and Social Research', 2),
#  ('University of California at Santa Cruz', 2),
#  ...]

# %%
# Out:
# 8843
